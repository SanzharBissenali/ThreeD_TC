# %%
import json 

with open('threed_bosonic.json', 'r') as file:
    data = json.load(file)

# %%
hz_list = data['h_z']
E0_list = data['E0']

# %%
hz_list
# Out:
# [0.0,
#  0.039473684210526314,
#  0.07894736842105263,
#  0.11842105263157894,
#  0.15789473684210525,
#  0.19736842105263158,
#  0.23684210526315788,
#  0.2763157894736842,
#  0.3157894736842105,
#  0.35526315789473684,
#  0.39473684210526316,
#  0.43421052631578944,
#  0.47368421052631576,
#  0.513157894736842,
#  0.5526315789473684,
#  0.5921052631578947,
#  0.631578947368421,
#  0.6710526315789473,
#  0.7105263157894737,
#  0.75]

# %%
E0_list
# Out:
# [-32.12065808552639,
#  -32.13904191503437,
#  -32.196509685311746,
#  -32.29684358198118,
#  -32.44876562467586,
#  -32.66834325559556,
#  -32.98040409506598,
#  -33.410081066278764,
#  -33.962009505326094,
#  -34.614408601729906,
#  -35.33795893279435,
#  -36.10993104149259,
#  -36.91554907835895,
#  -37.74545710542408,
#  -38.59356246652325,
#  -39.45573041168606,
#  -40.32904134254434,
#  -41.2113622667341,
#  -42.10109023674588,
#  -42.9969922377335]
